# %% [markdown]
# # 02 — Exploratory Data Analysis
#
# Purpose: calculate and document evidence-based descriptive, missingness, target, group, cabin, and spending analyses. No findings have been added yet.
